# %% [markdown]
# # import data JSON

# %% [markdown]
# Import data json disini menggunakan pandas,yaitu read_json()

# %%
import pandas as pd
import json

# %%
with open('dataset/tensi.json', 'r') as f:
    data = json.load(f)

# %%
data
# Out:
# [{'kategori': 'kabar_baik',
#   'pertanyaan': ['baik',
#    'baik-baik saja',
#    'sangat baik',
#    'aku baik',
#    'aku baik-baik saja',
#    'aku merasa baik',
#    'Kabar saya baik',
#    'Kabar saya baik-baik saja',
#    'Saya merasa sangat baik',
#    'Saya sehat-sehat saja',
#    'Saya merasa baik-baik saja, terima kasih',
#    'Alhamdulillah, kabar saya baik',
#    'Kabar saya cukup baik',
#    'Saya dalam keadaan baik',
#    'Saya merasa baik dan sehat',
#    'sehat',
#    'sangat sehat',
#    'aku merasa sehat',
#    'Saya merasa sangat sehat',
#    'Alhamdulillah, saya dalam keadaan sehat',
#    'Kabar saya baik-baik saja, dan kesehatan saya juga baik-baik saja',
#    'Saya dalam kondisi sehat',
#    'Saya merasa sehat dan bugar',
#    'Kondisi kesehatan saya cukup baik',
#    'Saya merasa sehat dan kuat',
#    'Lagi oke-oke aja nih kak',
#    'tidak enak badan',
#    'kurang enak badan',
#    'sakit',
#    'tidak sehat',
#    'aku sedang tidak sehat',
#    'aku kurang sehat',
#    'tidak baik',
#    'tidak enak badan',
#    'kurang baik'],
#   'jawaban': 'apa ada yang ingin kamu tanyakan atau lakukan?, tanyakan saja ya kepada aku tensibot'},
#  {'kategori': 'kabar_tidak_baik',
#   'pertanyaan': ['tidak enak badan',
#    'kurang enak badan',
#    'saya kurang enak badan',
#    'aku merasa tidak enak badan',
#    'badan ku kurang enak',
#    'badan ku terasa tidak enak',
#    'merasakan kurang enak badan',
#    'saya tidak enak badan',
#    'sakit',
#    'aku sakit',
#    'aku merasakan sakit',
#    'saya sakit',
#    'tidak sehat',
#    'aku sedang tidak sehat',
#    'aku terasa tidak sehat',
#    'tidak merasa sehat saat ini',
#    'saya terasa kurang baik',
#    'badanku terasa tidak enak',
#    'lagi tidak enak badan',
#    'tidak enak badan untuk saat ini',
#    'aku kurang sehat',
#    'tidak baik',
#    'tidak enak badan',
#    'kurang baik',
#    'aku kurang baik',
#    'kurang baik dan tidak enak badan',
#    'badan ku terasa sakit',
#    'aku kurang sehat akhir-akhir ini'],
#   'jawaban': 'semoga cepat sembuh ya kak. apa ada yang ingin kamu tanyakan atau lakukan?, tanyakan saja ya kepada aku tensibot'},
#  {'kategori': 'info_dev_tensibot',
#   'pertanyaan': ['siapa yang membuat tensibot?',
#    'Pembuat tensibot siapa?',
#    'Siapakah yang menciptakan tensibot?',
#    'siapa yang menciptakan tensibot?',
#    'Siapa pencipta tensibot?',
#    'Siapa yang membuat tensibot ini?',
#    'Siapa yang bikin tensibot?',
#    'Siapa yang ngebikin tensibot?',
#    'siapa yang mengembangkan tensibot?',
#    'tensibot dibuat oleh siapa?',
#    'saya ingin tahu siapa yang membuat tensibot?',
#    'aku penasaran siapa yang membuat tensibot?',
#    'aku ingin tahu siapa yang membuat tensibot',
#    'tensibot dibuat oleh siapa?',
#    'yang buat tensibot siapa ya?',
#    'siapa sih yang buat tensibot?',
#    'siapa yang buat chatbot ini?',
#    'siapa ya yang buat chatbot ini ?',
#    'yang buat tensibot itu siapa?',
#    'yang buat chatbot ini siapa?',
#    'siapa sih yang buat ni chatbot?',
#    'pengen tahu dong siapa yang buat tensibot',
#    'aku pengen tahu ni yang buat tensibot siapa ya?',
#    'aku penasaran siapa yang membuat tensibot?',
#    'penasaran banget siapa yang menciptakan tensibot?',
#    'pembuat tensibot itu sapa sih kalo boleh tahu?',
#    'aku suka tensibot, siapa ya yang membuat tensibot?',
#    'yang buat kamu siapa nih?',
#    'yang menciptakan kamu siapa nih?'],
#   'jawaban': 'Tensibot adalah chatbot yang dibuat oleh Zaki Rusydi sebagai tugas akhir. Tensibot dapat membantu pengguna dalam menyelesaikan masalah tentang tekanan darah. Chatbot ini dapat memberikan informasi tentang tekanan darah normal, cara mengukur tekanan darah, dan juga dapat memberikan saran tentang cara mengatasi tekanan darah tinggi atau rendah.'},
#  {'kategori': 'info_tensibot',
#   'pertanyaan': ['apa itu tensibot',
#    'sebutkan defenisi dari tensibo?',
#    'apa yang dimaksud dengan tensibot?',
#    'Tensibot adalah?',
#    'apa fungsi dari tensibot?',
#    'kenalin dong tensibot?',
#    'tensibot apa?',
#    'tensibot siapa?',
#    'tensibot itu apa ya?',
#    'tensibot itu apa manfaatnya?',
#    'tenibot itu apa, jelasin dong?',
#    'tensibot itu apa? jelasin dong',
#    'jelaskan apa itu tensibot?',
#    'jelaskan tesibot itu apa?',
#    'apasih tensibot itu?',
#    'apa fungsi tensibot',
#    'tensibot itu apa?',
#    'kamu itu apa ya?',
#    'tensibot itu robot apa ya?',
#    'aku penasaran apa fungsi dari tensibot',
#    'fungsi dari tensibot',
#    'tensibot berfungsi untuk?',
#    'fungsi tensibot itu buat apasih?',
#    'aku bingung, tensibot berfungsi buat apa ya?',
#    'tensibot itu fungsinya buat apa ya?',
#    'tensibot itu apaan sih?',
#    'tensibot itu robot seperti apa ya?',
#    'penasaran tensibot berfungsi buat apa?'],
#   'jawaban': 'tensibot merupakan sistem chatbot. chatbot ini dapat membantu kamu untuk mendiagnosa dan memberikan penanganan untuk penyakit hipertensi. \nApakah ada yang kakak ingin tanyakan lagi seputar tensibot atau hipertensi?'},
#  {'kategori': 'info_hipertensi',
#   'pertanyaan': ['apa itu hipertensi?',
#    'Apa yang dimaksud dengan hipertensi?',
#    'Hipertensi apa artinya?',
#    'Bagaimana pengertian dari hipertensi?',
#    'Hipertensi secara umum apa artinya?',
#    'Hipertensi itu sebenernya apa?',
#    'Hipertensi itu apaan sih?',
#    'Hipertensi itu artinya apa?',
#    'Hipertensi itu maksudnya apa?',
#    'Hipertensi itu apaan yaa?',
#    'Hipertensi itu apaan tuh?',
#    'saya ingin mengehtahui hipertensi itu apa?',
#    'coba jelasin apa itu hipertensi',
#    'aku mau tau arti dari hipertensi',
#    'hipertensi itu penyakit seperti apa?',
#    'Apa arti hipertensi ?',
#    'apa sih arti hipertensi?',
#    'hipertensi itu apa ya?',
#    'hipertensi itu apaan ya?',
#    'coba jelaskan apa itu hipertensi?',
#    'hipertensi itu apasih?',
#    'hmm hipertensi itu apa ya?',
#    'coba tensbot jelaskan apa itu hipertensi?',
#    'jelaskan mengenai hipertensi',
#    'pengertian dari hipertensi',
#    'hipertensi itu penyakit seperti apa?',
#    'hipertensi itu apa ?'],
#   'jawaban': 'Hipertensi adalah kondisi saat tekanan darah tinggi melebihi batas normal. Bisa menyebabkan kerusakan pada jantung, ginjal, dan pembuluh darah. Penyakit hipertensi sendiri memiliki beberapa gejala, dan juga terdapat beberapa obat medis untuk mengobati hipertensi.'},
#  {'kategori': 'info_gejala_hipertensi',
#   'pertanyaan': ['apa saja gejala hipertensi?',
#    'saya ingin mengehtahui gejala hieprtensi',
#    'apatuh gejala hipertensi?',
#    'Gimana gejalanya kalo pengidap hipertensi?',
#    'Apa tanda-tanda kalo seseorang lagi kena hipertensi?',
#    'Kalo pengidap hipertensi itu gejalanya apa aja?',
#    'Apa saja yang bisa jadi tanda kalo seseorang lagi kena hipertensi?',
#    'Apa gejala-gejala yang muncul kalo seseorang lagi kena hipertensi?',
#    'Dapatkah kamu menyebutkan gejala-gejala yang muncul dari hipertensi?',
#    'apa gejala yang ditimbul akibat hipertensi?',
#    'Dalam kondisi hipertensi, gejala apa saja yang dapat terjadi?',
#    'Bagaimana gejala yang dapat ditimbulkan oleh hipertensi?',
#    'Gejala apa saja yang ditimbulkan oleh kondisi hipertensi?',
#    'Gejala hipertensi apa aja sih?',
#    'Apa tanda-tanda kalo kita lagi kena hipertensi?',
#    'Kalo hipertensi itu gejalanya apa aja?',
#    'Apa yang bisa jadi tanda kalo kita lagi kena hipertensi?',
#    'Kalo kita lagi kena hipertensi, gejalanya apa aja?',
#    'Apa tanda-tanda yang muncul kalo kita lagi kena hipertensi?'],
#   'jawaban': 'adapun gejala dari penyakit hipertensi yaitu Sakit, kepala, Pusing, Gelisah, Penglihatan kabur, Mudah lelah, Jantung berdebar-debar, Sakit dada, Tidak merasakan gejala, dan juga tekanan dara diatas normal.'},
#  {'kategori': 'info_obat_hipertensi',
#   'pertanyaan': ['Apa saja obat untuk mengobati hipertensi?',
#    'Apa jenis obat yang digunakan untuk mengatasi hipertensi?',
#    'Ada apa aja obat buat ngatasin hipertensi?',
#    'Apa sih obat yang dipake buat nanganin hipertensi?',
#    'Apa obat-obat yang rekomendasikan buat ngatasin hipertensi?',
#    'Ada apa aja obat buat ilangin hipertensi?',
#    'Apa sih obat yang dipake buat ilangin hipertensi?',
#    'sebutkan rekomendasi obat untuk hipertensi',
#    'obat untuk hipertensi',
#    'obat hipertensi',
#    'Apa obat-obat yang rekomendasikan buat ilangin hipertensi?',
#    'rekomendasi obat untuk hipertensi',
#    'obat untuk hipertensi',
#    'rekomendasi obat untuk hipertensi',
#    'Ada berapa macam obat yang bisa dipake buat ilangin hipertensi?',
#    'Apa beda-bedanya obat-obat buat ilangin hipertensi?'],
#   'jawaban': 'ada beberapa obat yang dapat membantu menangani tekanan darah tinggi yaitu: \n=Hidroclorthiazide \n=Captopril, dan \n=Amlodipine.'},
#  {'kategori': 'cek_tekanan_darah',
#   'pertanyaan': ['saya ingin melakukan pemeriksaan hipertensi',
#    'pemeriksaan hipertensi',
#    'aku mau cek tekanan darah',
#    'gue pengen check hipertensi',
#    'ingin cek hipertensi',
#    'mau pemeriksaan hipertensi',
#    'check up tekanan darah',
#    'ingin tau kondisi tekanan darah',
#    'pengen cek hipertensi',
#    'mau tau kondisi tekanan darah',
#    'Saya ingin melakukan pemeriksaan terkait hipertensi',
#    'Saya ingin mengecek kondisi hipertensi saya',
#    'Saya ingin menjalani pemeriksaan tekanan darah',
#    'Saya ingin mengetahui kondisi hipertensi saya',
#    'aku mau cek hipertensi',
#    'saya ingin melakukan pengecekan tekanan darah',
#    'pengen cek tekanan',
#    'mau tau kondisi darah tinggi'],
#   'jawaban': 'Apakah kamu rutin berolahraga atau melakukan  aktifitas?'},
#  {'kategori': 'info_kegiatan_olahraga',
#   'pertanyaan': ['rutin',
#    'rutin berolahraga',
#    'rutin olahraga',
#    'saya rutin olahraga',
#    'saya rutin berolahraga',
#    'iya saya rutin olahraga',
#    'sering berolahraga',
#    'sering olahraga',
#    'saya sering olahraga',
#    'saya sering berolahraga',
#    'iya saya sering olahraga',
#    'jarang',
#    'jarang olahraga',
#    'Jarang berolahraga',
#    'saya jarang olahraga',
#    'saya jarang berolahraga',
#    'iya saya jarang olahraga',
#    'ya saya jarang berolahraga',
#    'kadang-kadang berolahraga',
#    'kadang-kadang saya berolahraga',
#    'terkadang saya berolahraga',
#    'terkadang berolahraga',
#    'sesekali saya berolahraga',
#    'sesekali berolahraga',
#    'tidak pernah',
#    'terkadang',
#    'tidak pernah olahraga',
#    'tidak pernah berolahraga',
#    'saya tidak pernah berolahraga',
#    'saya tidak pernah olahraga'],
#   'jawaban': ' Apakah kamu perokok atau sering menghisap asap rokok?'},
#  {'kategori': 'info_perokok_aktif',
#   'pertanyaan': ['tidak, saya tidak merokok',
#    'saya bukan perokok aktif',
#    'saya tidak pernah merokok',
#    'saya tidak merokok',
#    'tidak merokok',
#    'bukan perokok aktif',
#    'bukan perokok',
#    'iya, saya perokok aktif',
#    'saya perokok aktif',
#    'iya saya adalah perokok aktif',
#    'merokok',
#    'perokok',
#    'merokok, ya saya perokok aktif',
#    'ya saya sering menghisap asap rokok',
#    'saya sering menghisap asap rokok',
#    'sering menghisap asap rokok',
#    'sering terhirup asap rokok',
#    'saya sering terhirup asap rokok',
#    'sering terhirup asap rokok',
#    'sering terpapar asap rokok',
#    'saya sering sekali terpapar asap rokok',
#    'terpapar asap rokok'],
#   'jawaban': ' apakah kamu pernah/sering meminum alkohol (Minuman Keras)?'},
#  {'kategori': 'info_kegiatan_minualkohol',
#   'pertanyaan': ['pernah',
#    'tidak, saya tidak minum miras',
#    'saya tidak pernah minum minuman keras',
#    'tidak minum minuman beralkohol',
#    'saya tidak pernah meminum minuman beralkohol',
#    'iya saya tidak pernah minum miras',
#    'iya saya sering minum minuman keras',
#    'iya saya sering minum miras',
#    'iya saya sering mengkonsumsi miras',
#    'saya sering mengkonsumsi minuma keras',
#    'tidak pernah',
#    'tidak terlalu sering',
#    'jarang',
#    'sesekali',
#    'minum miras',
#    'minum minuman beralkohol',
#    'mengkonsumsi miras',
#    'Saya tidak pernah meminum alkohol',
#    'Saya merupakan peminum alkohol yang jarang',
#    'Saya memilih untuk tidak minum alkohol',
#    'Alkohol? ngga saya ngga minum alkohol',
#    'Alkohol? gak pernah minum, gak suka efeknya',
#    'Gak pernah minum alkohol, lebih suka minum air putih',
#    'Gak suka alkohol, gak ada sensasi yang menyenangkan',
#    'Alkohol? Sering minum, tapi gak pernah mabuk',
#    'Sering minum alkohol, tapi gak pernah kebablasan',
#    'Alkohol? Sering minum, tapi gak pernah kebablasan',
#    'Sering minum alkohol, tapi gak pernah kebablasan',
#    'Saya sering minum alkohol dengan takaran yang wajar',
#    'Saya merupakan peminum alkohol yang rutin',
#    'Saya meminum alkohol dengan takaran yang sesuai'],
#   'jawaban': ' Apa gejala yang kamu rasakan akhir-akhir ini? \n- sakit kepala \n- pusing \n- gelisah \n- penglihatan kabur \n- mudah lelah \n-  jantung berdebar-deba \n- sakit dada \n- tidak ada gejala \n- lainnya'},
#  {'kategori': 'gejala',
#   'pertanyaan': ['saya merasakan sakit kepala',
#    'sakit kepala',
#    'kepala saya terasa sakit',
#    'saya merasakan gejala sakit kepala',
#    'pusing',
#    'kepala pusing',
#    'saya merasakan pusing',
#    'kepala saya terasa pusing',
#    'saya merasakan gejala pusing',
#    'gelisah',
#    'saya merasakan gelisah',
#    'saya gelisa',
#    'terasa gelisah',
#    'saya terasa gelisah',
#    'merasa tidak tenang',
#    'saya merasa kurang tenang',
#    'penglihatan kabur',
#    'penglihatan saya terasa kabur',
#    'penglihatan saya terasa kabur akhir - akhir ini',
#    'penglihatan kurang jelas',
#    'penglihatan menjadi kurang jelas',
#    'kurang jelas dalam melihat',
#    'kabur dalam melihat',
#    'mata menjadi kabur',
#    'mata menjadi kurang jelas',
#    'mata menjadi kabur dalam melihat',
#    'mata menjadi kurang dalam melihat',
#    'mudah lelah',
#    'saya merasakan gejala mudah lelas',
#    'terasa mudah lelas',
#    'mudah kelelahan',
#    'cepat lelah',
#    'merasa cepat lelah',
#    'merasakan gejala mudah lelah',
#    'jantung berdebar debar',
#    'dada terasa sakit',
#    'sakit dada',
#    'sering mengalami sakit dada',
#    'saya mengalami sakit dada',
#    'sering merasakan sakit dada',
#    'dada terasa sakit',
#    'tidak merasakan apa-apa',
#    'tidak ada gejala',
#    'tidak merasakan apa-apa',
#    'ngga ngerasa apa-apa'],
#   'jawaban': 'Apakah kamu ingin memeriksa tekanan darah? (Ya ingin/Tidak ingin)'},
#  {'kategori': 'tidak_cek_hipertensi',
#   'pertanyaan': ['tidak',
#    'tidak ingin',
#    'tidak ingin tahu',
#    'nggak mau',
#    'aku ngga mau',
#    'aku ngga mau tahu',
#    'Maaf, saya tidak ingin',
#    'Saya tidak dapat menerima permintaan ini',
#    'Saya tidak dapat menerima permintaan ini',
#    'Maaf, saya tidak dapat menyetujui permintaan ini',
#    'Nggak mau deh',
#    'Nggak usah deh',
#    'Udah, saya tidak mau',
#    'Eits, saya tidak mau.',
#    'Gak mau, bro',
#    'Nggak mau ah',
#    'Gak mau',
#    'Tidak mau, tensibot',
#    'Gak mau deh, tensibot',
#    'Nggak mau, Tensibot'],
#   'jawaban': 'Baik kakaaa.'},
#  {'kategori': 'bye',
#   'pertanyaan': ['da da',
#    'da',
#    'terimakasih tesibot',
#    'oke terimkasih tensibot',
#    'dada tensibot',
#    'terimakasih',
#    'terimakasih tensibot',
#    'terimakasih banyak',
#    'makasih',
#    'makasih tensibot',
#    'makasih banyak',
#    'bye',
#    'bye tensibot',
#    'bye bye',
#    'selamat tinggal tensibot',
#    'selamat tinggal',
#    'wah makasih banyak tensibot',
#    'terimakasih sekali tensibot',
#    'makasih ya tensbot buat sarannya',
#    'makasih nih buat saran yang diberikan',
#    'dada makasih banyak lo saran yang kamu kasih',
#    'dada tensibot, terimakasih sarannya',
#    'makasih ya saran yang bermanfaatnya',
#    'makasih banget sarannya',
#    'makasih banyak saran yang kamu kasih',
#    'sarannya bagus makasih ya',
#    'sarannya memuaskan makasih banyak',
#    'sarannya bagus, makasih'],
#   'jawaban': 'iya kaka, semoga apa yang diberikan tensibot bermanfaat ya buat kamu. kalau masih bingung kaka boleh tanya lagi sama tensibot seputar hipertensi'},
#  {'kategori': 'penjelasan_Hidroclorthiazide',
#   'pertanyaan': ['jelaskan apa itu Hidroclorthiazide!',
#    'Hidroclorthiazide itu apasih?',
#    'apa itu Hidroclorthiazide?',
#    'apasih Hidroclorthiazide?',
#    'coba jelaskan Hidroclorthiazide',
#    'jelaskan mengenai obat Hidroclorthiazide',
#    'pengen tahu apa itu obat Hidroclorthiazide',
#    'tensibot, obat Hidroclorthiazide itu apa sih?',
#    'aku pengen tahu Hidroclorthiazide itu apa?',
#    'obat Hidroclorthiazide itu seperti apa?',
#    'jelaskan kepada saya mengenai Hidroclorthiazide',
#    'Hidroclorthiazide itu apa?',
#    'gua mau tau tentang Hidroclorthiazide',
#    'berikan penjelasan mengenai obat Hidroclorthiazide',
#    'Hidroclorthiazide',
#    'penjelasan mengenai obat Hidroclorthiazide'],
#   'jawaban': 'Hydrochlorothiazide merupakan sejenis obat yang digunakan untuk meredakan tekanan darah tinggi pada individu yang mengidap hipertensi. Selain itu, obat ini juga memiliki kemampuan untuk mengatasi kondisi edema, yang terjadi ketika terjadi penumpukan cairan dalam jaringan tubuh, seperti yang sering terjadi pada pasien dengan kondisi gagal jantung atau sirosis hati. \n Jika ada pertanyaan lain mengenai obat ini tanyakan saja kepada aku ya kak'},
#  {'kategori': 'before_konsumsi_Hydrochlorothiazide',
#   'pertanyaan': ['apa yang harus dilakukan sebelum mengkonsumsi Hydrochlorothiazide?',
#    'apa persiapan sebelum mengkonsumsi Hydrochlorothiazide?',
#    'apa langkah khusu yang harus dilakukan sebelum mengkonsumsi Hydrochlorothiazide',
#    'Apa yang perlu dilakukan sebelum memulai penggunaan Hydrochlorothiazide?',
#    'Bagaimana persiapan sebelum mengonsumsi Hydrochlorothiazide?',
#    'apakah ada peringatan sebelum mengkonsumsi Hydrochlorothiazide?',
#    'apa saja langkah-langkah sebelum mengkonsumsi Hydrochlorothiazide?',
#    'apa yang dilakukan sebelum mengkonsumsi Hydrochlorothiazide?',
#    'yang harus di ikuti sebelum mengkonsumsi Hydrochlorothiazide?',
#    'step apa yang harus dilakuka sebelum mengkonsumsi Hydrochlorothiazide?'],
#   'jawaban': '1. Tidak boleh mengkonsumsi Hydrochlorothiazide jika ada alergi terhadap obat ini atau obat sulfa \n2. Jangan mengkonsi Hydrochlorothiazide jika tidak bisa buang air kecil \n3.beritahu dokter jika kamu mengalami  glaukoma,  ginjal, hati, asam urat, diabetes, asma, dan gangguan paratiroid \n4. jangan mengkonsumsi alkohol \n5. jangan melakukan aktifitas yang memerlukan fokus yang tinggi \n6. beritahukan dokter jika sedang hamil, menyusui, dan sedang menjalani program kehamilan \n7. beritahu dokter jika sedang mengkonsumsi obat lain \n8. pergi ke dokter jika mengalami alergi \n9. hindari paparan sinar matahari yang terlalu lama'},
#  {'kategori': 'efek_Hidroclorthiazide',
#   'pertanyaan': ['apa efek samping dari Hidroclorthiazide?',
#    'efek samping Hidroclorthiazide',
#    'apa saja efek samping dari Hidroclorthiazide',
#    'pengen tahu efek samping Hidroclorthiazide?',
#    'apasih efek samping Hidroclorthiazide',
#    'efek samping dari obat Hidroclorthiazide',
#    'efek dari Hidroclorthiazide',
#    'tensibot, apa efek samping dari obat Hidroclorthiazide?',
#    'Apa efek samping umum yang dapat ditimbulkan oleh Hidroklortiazid?',
#    'Apakah terdapat risiko dehidrasi akibat penggunaan Hidroklortiazid?',
#    'kalau minum Hidroklortiazid, apa efek sampingya?'],
#   'jawaban': '1. Pusing \n2. sakit kepala \n3. sering buang air kecil \n4. sakit maag \n5. hilang nafsu makan \n6. Rambut Rontok'},
#  {'kategori': 'Penjelasan_Catopril',
#   'pertanyaan': ['Captopril itu apa?',
#    'mau tahu Captopril itu apa?',
#    'Apasih itu Captopril?',
#    'Wah Captopril itu apa ya?',
#    'ceptropil apa tuh?',
#    'pengertian Captopril?',
#    'Captopril itu apaan?',
#    'apa itu Captopril?',
#    'pengen tahu Captopril itu apa?',
#    'coba jelasin tentang Captopril',
#    'tensibot jelasin tentang Captopril dong',
#    'aku pengen tahu apa itu Captopril',
#    'Captopril itu apa ya',
#    'mau nanya Captopril itu apa?',
#    'jelaskan apa itu Captopril'],
#   'jawaban': 'Captopril adalah obat yang digunakan untuk hipertensi, gagal jantung, dan nefropati diabetik. Obat ini dapat digunakan sendiri atau dikombinasikan dengan diuretik. Captopril juga membantu pemulihan setelah serangan jantung'},
#  {'kategori': 'before_konsumsi_Catopril',
#   'pertanyaan': ['Apa peringatan utama sebelum mengonsumsi Captopril?',
#    'Apakah ada kondisi medis tertentu yang perlu diperhatikan sebelum menggunakan Catopril?',
#    'Apakah Captopril dapat menyebabkan reaksi alergi?',
#    'Bagaimana cara penggunaan Captopril yang benar?',
#    'apakah ada yang dilakukan mengkonsumsi catropil?',
#    'Ada yang perlu diinget sebelum minum Captopril?',
#    'Bisa gak sih alergi sama Captopril?',
#    'Kondisi kesehatan apa yang harus diperhatiin sebelum minum Captopril?',
#    'apa yang harus dilakukan sebelum mengkonsumsi captropil?',
#    'apasih yang harus diikuti sebelum mengkonsumsi captropil?',
#    'apa saja nih yang harus dilakukan sbelum mengkonsumsi captropil?',
#    'tensibot apa saja ya yang harus dilakukan agar dapat mengkonsumsi captropil?'],
#   'jawaban': '1. memberitahukan riwayat alergi kepada dokter \n2.memberitahukan dokter jika mempunyai riwayat angiodema \n3. jangan melkukan  kegiatan yang memerlukan fokus yang tinggi \n4. tidak boleh mengkonsumsi cetropil jika mengalami penyakit ginjal, dan diabetes dengan pengobatan aliskiren \n5. memberitahukan obat antihipertensi yang sedang digunakan \n6. segera menghubungi dokter jika mengalami alergi'},
#  {'kategori': 'efek_Captopril',
#   'pertanyaan': ['Apa efek samping umum yang biasanya terjadi saat menggunakan Captopril?',
#    'apa ya efek samping dari mengkonsumsi captropil',
#    'Apakah Captropil memiliki efek samping yang umum?',
#    'Apakah Captropil menimbulkan efek samping?',
#    'apa saja efek samping dari captropil?',
#    'apasih efek samping dari captropil',
#    'mau nanya nih apa ya efek samping dari captropil',
#    'sebutkan efek samping dari obat captropil',
#    'apa ya efek samping dari obat captropil?',
#    'jelaskan efek samping dari obat captropil',
#    'apa efek samping dari mengkonsumsi captropil?',
#    'efek samping setelah mengkonsumsi captropil',
#    'efek samping yang timbul setelah mengkonsumsi obat captropil'],
#   'jawaban': '1. Pusing berat \n2. kadar kalium dalam dara menjadi tinggi \n3. sesak napas \n4. nyeri dada \n5. gangguan fungsi ginjal \n6. gangguan fungsi hati \n7. menyebabkan angiodema'},
#  {'kategori': 'penjelasan_Amlodipine',
#   'pertanyaan': ['apa itu Amlodipine?',
#    'jelasin mengenai Amlodipine',
#    'Amlodipine itu apa ya?',
#    'aku ngga tau nih Amlodipine itu apa, jelasin dong',
#    'tensibot aku mau nanya Amlodipine itu apa?',
#    'aku pengen tahu nih apa itu obat Amlodipine',
#    'jelasin dong Amlodipine itu apa?',
#    'berikan penjelasan mengenai Amlodipine',
#    'menurut tensibot Amlodipine itu apasih?',
#    'Amlodipine itu apa?',
#    'coba tensibot jelaskan mengenai Amlodipine?',
#    'Amlodipine adalah',
#    'gua mau tau tentang obat Amlodipine',
#    'aku tidak tahu apa itu Amlodipine, coba dijelaskan',
#    'masih bingun apa itu Amlodipine'],
#   'jawaban': 'Amlodipine adalah obat untuk hipertensi dan nyeri dada kronis (angina pektoris) akibat penyakit jantung koroner, dapat digunakan sendiri atau dikombinasikan dengan obat lain.'},
#  {'kategori': 'before_konsumsi_Amlodipine',
#   'pertanyaan': ['yang harus dilakukan sebelum mengkonsumsi amlodipine',
#    'sebelum minum obat amlodipine',
#    'kegiatan yang dilakukan sebelum mengkonsumsi amlodipine',
#    'aktifitas yang dilakukan sebelum mengkonsumsi amlodipine',
#    'kegiatan yang dihindari sebelum mengkonsumsi amlodipine',
#    'berikan penjelasan mengenai pantangan yang ada saat mengkonsumsi amlodipine',
#    'pantangan saat mengkonsumsi amlodipine',
#    'yang harus dihindari saat ingin mengkonsumsi amlodipine',
#    'yang tidak boleh dilakukan sebelum meminum amlodipine',
#    'kamu tau ngga pantangan sebelum mengkonsumsi amlodipine?',
#    'apa ya yang harus dihindari saat ingin mengkonsumsi amlodipine?',
#    'bingung apa ya yang harus dihindari sebelum mengkonsumsi amlodipine?',
#    'tensibot coba sebutin pantangan saat mengkonsumsi amlodipine',
#    'sebutin dong yang harus dihindari saat ingin minum obat Amlodipine'],
#   'jawaban': '1. memberitahukan doktersedang mengidap penyakit diabaetes, liver dan gagal jantung \n2. tidak boleh melakukan aktifitas yang membutuhkan fokus yang tinggi \n3. meberitahukan dokter jika ingin menggunakan amlodipineuntuk tindakan operasi \n3. memberitahukan dokter jika sedang mengkonsumsi obat obat tan lainnya \n4 menghubungi dokter jika mengalami alergi'},
#  {'kategori': 'efek_Amlodipine',
#   'pertanyaan': ['sebutin dong efek dari amlodipine',
#    'efek samping dari amlodipine apa ya?',
#    'sebutkan indikasi dari penggunaan amlodipine',
#    'efek sampingdari obat amlodipine sih?',
#    'belum tahu efek samping dari amlodipine',
#    'kamu tau ngga efek sampin dari amlodipine?',
#    'aku bingung apa efek samping dari amlodipine',
#    'tensibot sebutin dong apa efek samping dari amlodipine',
#    'aku ngga tau nih apa efek samping dari amlodipine',
#    'lo tau ngga efek samping amlodipine',
#    'coba sebutin dong efek dari amlodipine',
#    'efek samping yang umum terjadi setelah mengkonsumsi amlodipine apa yaa?',
#    'aku ngga tahu banget nih efek samping ',
#    'efek dari amlodipine',
#    'efek samping amlodipine'],
#   'jawaban': '\n1. Mengantuk \n2. Pusing \n3. Menyebabkan lelah \n4. Sakit Perut \n5. Mual \n6. Memerah pada kulit Wajah dan leher'}]

# %%
print(data)
# Out:
# [{'kategori': 'kabar_baik', 'pertanyaan': ['baik', 'baik-baik saja', 'sangat baik', 'aku baik', 'aku baik-baik saja', 'aku merasa baik', 'Kabar saya baik', 'Kabar saya baik-baik saja', 'Saya merasa sangat baik', 'Saya sehat-sehat saja', 'Saya merasa baik-baik saja, terima kasih', 'Alhamdulillah, kabar saya baik', 'Kabar saya cukup baik', 'Saya dalam keadaan baik', 'Saya merasa baik dan sehat', 'sehat', 'sangat sehat', 'aku merasa sehat', 'Saya merasa sangat sehat', 'Alhamdulillah, saya dalam keadaan sehat', 'Kabar saya baik-baik saja, dan kesehatan saya juga baik-baik saja', 'Saya dalam kondisi sehat', 'Saya merasa sehat dan bugar', 'Kondisi kesehatan saya cukup baik', 'Saya merasa sehat dan kuat', 'Lagi oke-oke aja nih kak', 'tidak enak badan', 'kurang enak badan', 'sakit', 'tidak sehat', 'aku sedang tidak sehat', 'aku kurang sehat', 'tidak baik', 'tidak enak badan', 'kurang baik'], 'jawaban': 'apa ada yang ingin kamu tanyakan atau lakukan?, tanyakan saja ya kepada aku tensibot'}, {'kategori': 'kabar_tidak_baik', 'pertanyaan': ['tidak enak badan', 'kurang enak badan', 'saya kurang enak badan', 'aku merasa tidak enak badan', 'badan ku kurang enak', 'badan ku terasa tidak enak', 'merasakan kurang enak badan', 'saya tidak enak badan', 'sakit', 'aku sakit', 'aku merasakan sakit', 'saya sakit', 'tidak sehat', 'aku sedang tidak sehat', 'aku terasa tidak sehat', 'tidak merasa sehat saat ini', 'saya terasa kurang baik', 'badanku terasa tidak enak', 'lagi tidak enak badan', 'tidak enak badan untuk saat ini', 'aku kurang sehat', 'tidak baik', 'tidak enak badan', 'kurang baik', 'aku kurang baik', 'kurang baik dan tidak enak badan', 'badan ku terasa sakit', 'aku kurang sehat akhir-akhir ini'], 'jawaban': 'semoga cepat sembuh ya kak. apa ada yang ingin kamu tanyakan atau lakukan?, tanyakan saja ya kepada aku tensibot'}, {'kategori': 'info_dev_tensibot', 'pertanyaan': ['siapa yang membuat tensibot?', 'Pembuat tensibot siapa?', 'Siapakah yang menciptakan tensibot?', 'siapa yang menciptakan tensibot?', 'Siapa pencipta tensibot?', 'Siapa yang membuat tensibot ini?', 'Siapa yang bikin tensibot?', 'Siapa yang ngebikin tensibot?', 'siapa yang mengembangkan tensibot?', 'tensibot dibuat oleh siapa?', 'saya ingin tahu siapa yang membuat tensibot?', 'aku penasaran siapa yang membuat tensibot?', 'aku ingin tahu siapa yang membuat tensibot', 'tensibot dibuat oleh siapa?', 'yang buat tensibot siapa ya?', 'siapa sih yang buat tensibot?', 'siapa yang buat chatbot ini?', 'siapa ya yang buat chatbot ini ?', 'yang buat tensibot itu siapa?', 'yang buat chatbot ini siapa?', 'siapa sih yang buat ni chatbot?', 'pengen tahu dong siapa yang buat tensibot', 'aku pengen tahu ni yang buat tensibot siapa ya?', 'aku penasaran siapa yang membuat tensibot?', 'penasaran banget siapa yang menciptakan tensibot?', 'pembuat tensibot itu sapa sih kalo boleh tahu?', 'aku suka tensibot, siapa ya yang membuat tensibot?', 'yang buat kamu siapa nih?', 'yang menciptakan kamu siapa nih?'], 'jawaban': 'Tensibot adalah chatbot yang dibuat oleh Zaki Rusydi sebagai tugas akhir. Tensibot dapat membantu pengguna dalam menyelesaikan masalah tentang tekanan darah. Chatbot ini dapat memberikan informasi tentang tekanan darah normal, cara mengukur tekanan darah, dan juga dapat memberikan saran tentang cara mengatasi tekanan darah tinggi atau rendah.'}, {'kategori': 'info_tensibot', 'pertanyaan': ['apa itu tensibot', 'sebutkan defenisi dari tensibo?', 'apa yang dimaksud dengan tensibot?', 'Tensibot adalah?', 'apa fungsi dari tensibot?', 'kenalin dong tensibot?', 'tensibot apa?', 'tensibot siapa?', 'tensibot itu apa ya?', 'tensibot itu apa manfaatnya?', 'tenibot itu apa, jelasin dong?', 'tensibot itu apa? jelasin dong', 'jelaskan apa itu tensibot?', 'jelaskan tesibot itu apa?', 'apasih tensibot itu?', 'apa fungsi tensibot', 'tensibot itu apa?', 'kamu itu apa ya?', 'tensibot itu robot apa ya?', 'aku penasaran apa fungsi dari tensibot', 'fungsi dari tensibot', 'tensibot berfungsi untuk?', 'fungsi ...

# %% [markdown]
# # Mengubah data JSON ke dalam bentuk DataFrame

# %% [markdown]
# Mengubah data json kedalam bentuk DataFrame
#
# Dataframe merupakan data yang berbentuk tabel

# %%
kategori = []
pertanyaan = []
jawaban={}
for intent in data:
    jawaban[intent['kategori']]=intent['jawaban']
    for lines in intent['pertanyaan']:
        pertanyaan.append(lines)
        kategori.append(intent['kategori'])

# %%
df = pd.DataFrame({"kategori":kategori, "pertanyaan":pertanyaan})

# %%
#menampilkan dataframe
df
# Out:
#             kategori                                         pertanyaan
# 0         kabar_baik                                               baik
# 1         kabar_baik                                     baik-baik saja
# 2         kabar_baik                                        sangat baik
# 3         kabar_baik                                           aku baik
# 4         kabar_baik                                 aku baik-baik saja
# ..               ...                                                ...
# 492  efek_Amlodipine             coba sebutin dong efek dari amlodipine
# 493  efek_Amlodipine  efek samping yang umum terjadi setelah mengkon...
# 494  efek_Amlodipine             aku ngga tahu banget nih efek samping
# 495  efek_Amlodipine                               efek dari amlodipine
# 496  efek_Amlodipine                            efek samping amlodipine
#
# [497 rows x 2 columns]

# %%
df[70:100]
# Out:
#              kategori                                         pertanyaan
# 70  info_dev_tensibot                      Siapa yang ngebikin tensibot?
# 71  info_dev_tensibot                 siapa yang mengembangkan tensibot?
# 72  info_dev_tensibot                        tensibot dibuat oleh siapa?
# 73  info_dev_tensibot       saya ingin tahu siapa yang membuat tensibot?
# 74  info_dev_tensibot         aku penasaran siapa yang membuat tensibot?
# 75  info_dev_tensibot         aku ingin tahu siapa yang membuat tensibot
# 76  info_dev_tensibot                        tensibot dibuat oleh siapa?
# 77  info_dev_tensibot                       yang buat tensibot siapa ya?
# 78  info_dev_tensibot                      siapa sih yang buat tensibot?
# 79  info_dev_tensibot                       siapa yang buat chatbot ini?
# 80  info_dev_tensibot                   siapa ya yang buat chatbot ini ?
# 81  info_dev_tensibot                      yang buat tensibot itu siapa?
# 82  info_dev_tensibot                       yang buat chatbot ini siapa?
# 83  info_dev_tensibot                    siapa sih yang buat ni chatbot?
# 84  info_dev_tensibot          pengen tahu dong siapa yang buat tensibot
# 85  info_dev_tensibot    aku pengen tahu ni yang buat tensibot siapa ya?
# 86  info_dev_tensibot         aku penasaran siapa yang membuat tensibot?
# 87  info_dev_tensibot  penasaran banget siapa yang menciptakan tensibot?
# 88  info_dev_tensibot     pembuat tensibot itu sapa sih kalo boleh tahu?
# 89  info_dev_tensibot  aku suka tensibot, siapa ya yang membuat tensi...
# 90  info_dev_tensibot                          yang buat kamu siapa nih?
# 91  info_dev_tensibot                   yang menciptakan kamu siapa nih?
# 92      info_tensibot                                   apa itu tensibot
# 93      info_tensibot                    sebutkan defenisi dari tensibo?
# 94      info_tensibot                 apa yang dimaksud dengan tensibot?
# 95      info_tensibot                                   Tensibot adalah?
# 96      info_tensibot                          apa fungsi dari tensibot?
# 97      info_tensibot                             kenalin dong tensibot?
# 98      info_tensibot                                      tensibot apa?
# 99      info_tensibot                                    tensibot siapa?

# %% [markdown]
# # Preprocessing Data

# %%
import re
import Sastrawi
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# %% [markdown]
# ## Remove Punctuation

# %% [markdown]
# Remove punctuation berfungsi untuk menghilangkan tanda baca yang terdapat di dalam kalimat
#
# Ex: "Siapa yang membuat tensibot?" ==> "Siapa yang membuat tensbot"
#
# dari contoh yang ada dapat kita lihat bahwa tanda baca menjadi hilang

# %%
separator = '|'
hapus_tandabaca = '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{}~'
delete =str.maketrans(dict.fromkeys(hapus_tandabaca,' '))

# %%
df['pertanyaan'] = separator \
    .join(df['pertanyaan'].tolist()) \
    .translate(delete) \
    .split(separator)

# %%
#Menampilkan data pertanyaaan yang telah di remove tanda baca
print(df['pertanyaan'])
# Out:
# 0                                                   baik
# 1                                         baik baik saja
# 2                                            sangat baik
# 3                                               aku baik
# 4                                     aku baik baik saja
#                              ...
# 492               coba sebutin dong efek dari amlodipine
# 493    efek samping yang umum terjadi setelah mengkon...
# 494               aku ngga tahu banget nih efek samping
# 495                                 efek dari amlodipine
# 496                              efek samping amlodipine
# Name: pertanyaan, Length: 497, dtype: object

# %% [markdown]
# ## Stemming

# %% [markdown]
# Stemming berfungsi untuk mengubah suatu kata menjadi kata dasar.
#
# Ex: "Memakan" ==> "Makan"
#
# dapat kita lihat dari contoh dimana kata "Memakan" menjadi kata dasarnya yaitu "Makan". proses stemming disini menggunakan sastrawi

# %%
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# Melakukan lemmatization pada setiap baris di kolom 'question', 
df['pertanyaan'] = df['pertanyaan'].apply(lambda x: stemmer.stem(x))

# %%
# Menampilkan data yang telah di stemming menggunakan sastrawi
print(df['pertanyaan'])
# Out:
# 0                                                   baik
# 1                                         baik baik saja
# 2                                            sangat baik
# 3                                               aku baik
# 4                                     aku baik baik saja
#                              ...
# 492               coba sebutin dong efek dari amlodipine
# 493    efek samping yang umum jadi telah konsumsi aml...
# 494                aku ngga tahu banget nih efek samping
# 495                                 efek dari amlodipine
# 496                              efek samping amlodipine
# Name: pertanyaan, Length: 497, dtype: object

# %% [markdown]
# ## Stopword

# %%
# from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# # Membuat objek stopword remover
# factory = StopWordRemoverFactory()
# stopword = factory.create_stop_word_remover()

# # Menghilangkan stopwords dari setiap baris teks
# df['pertanyaan'] = df['pertanyaan'].apply(lambda x: stopword.remove(x))

# %%
# # Menampilkan hasil data setelah di stopword
# print(df['pertanyaan'].head(50))

# %% [markdown]
# ## Tokenizing

# %%
# Membuat fungsi tokenize untuk melakukan proses tokenizing menggunakan regex
def tokenize(questions):
    # Menggunakan \w+ untuk mencocokkan semua kecocokan karakter huruf 
    #dan angka, yang diinterpretasikan sebagai kata-kata
    tokens = re.findall(r'\w+', questions)
    return tokens

# Menerapkan fungsi tokenisasi ke setiap baris teks dalam kolom questions
df['pertanyaan'] = df['pertanyaan'].apply(tokenize)

# %%
vocabs = []

for x in df.pertanyaan:
    for y in x:
        vocabs.append(y)

# %%
len(vocabs)
# Out:
# 2259

# %%
def unique(list1):
 
    # initialize a null list
    unique_list = []
 
    # traverse for all elements
    for x in list1:
        # check if exists in unique_list or not
        if x not in unique_list:
            unique_list.append(x)
    return unique_list

# %%
vocabs = unique(vocabs)

# %%
len(vocabs)
# Out:
# 276

# %%
# menampilkan data yang telah di tokenizing
print(df['pertanyaan'])
# Out:
# 0                                                 [baik]
# 1                                     [baik, baik, saja]
# 2                                         [sangat, baik]
# 3                                            [aku, baik]
# 4                                [aku, baik, baik, saja]
#                              ...
# 492        [coba, sebutin, dong, efek, dari, amlodipine]
# 493    [efek, samping, yang, umum, jadi, telah, konsu...
# 494        [aku, ngga, tahu, banget, nih, efek, samping]
# 495                             [efek, dari, amlodipine]
# 496                          [efek, samping, amlodipine]
# Name: pertanyaan, Length: 497, dtype: object

# %% [markdown]
# # MODEL

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Mengubah data Hasil Tokenize Kedalam Bentuk Numerik

# %%
#Membuat objek CountVectorizer
vectorizer = CountVectorizer()

#Mengubah data tokenized menjadi bentuk numerik dengan menggunakan fit_transform
data_numerik = vectorizer.fit_transform(df['pertanyaan'].apply(lambda x: " ".join(x)))

#  Membuat dataframe baru yang berisi data numerik
X = pd.DataFrame(data_numerik.toarray(), columns=vectorizer.get_feature_names_out())

# %%
# Menampilkan hasil Data Numerik
x
# Out:
# ['efek', 'samping', 'amlodipine']

# %%
tensibot = X['tensibot']

tensibot [89:]
# Out:
# 89     2
# 90     0
# 91     0
# 92     1
# 93     0
#       ..
# 492    0
# 493    0
# 494    0
# 495    0
# 496    0
# Name: tensibot, Length: 408, dtype: int64

# %%
X['tinggal']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 492    0
# 493    0
# 494    0
# 495    0
# 496    0
# Name: tinggal, Length: 497, dtype: int64

# %%
# mencari index dengan kata yang memiliki nilai == 1
index = []
n =  X['tensibot']
for i in range(len(x)):
    if n[i] == 1 or n[i] == 2:
        index.append(i)

# %%
# Menampilkan index data pertanyaan dengan kata "tensibot"
index[:25]
# Out:
# []

# %% [markdown]
# ##  Naive Bayes

# %%
# Membuat objek MultinomialNB
model = MultinomialNB()

# Memisahkan data menjadi data latih dan data uji
X_train, X_test, y_train, y_test = train_test_split(data_numerik, df['kategori'], test_size=0.2)

# %%
# Melatih model dengan data latih
model.fit(X_train, y_train)
#Menguji model dengan data uji
y_pred = model.predict(X_test)

# %%
# Menampilkan hasil akurasi
print("Akurasi model: ", accuracy_score(y_test, y_pred))
# Out:
# Akurasi model:  0.87

# %% [markdown]
# ## Visualisasi

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Membuat confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Menyajikan confusion matrix dalam bentuk heatmap
sns.heatmap(cm, annot=True, fmt='d')
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import classification_report

# Menyajikan classification report
print(classification_report(y_test, y_pred))
# Out:
#                                      precision    recall  f1-score   support
#
#                 Penjelasan_Catopril       1.00      0.80      0.89         5
#          before_konsumsi_Amlodipine       0.60      1.00      0.75         3
#            before_konsumsi_Catopril       0.00      0.00      0.00         3
# before_konsumsi_Hydrochlorothiazide       0.00      0.00      0.00         0
#                                 bye       1.00      1.00      1.00         6
#                   cek_tekanan_darah       0.80      1.00      0.89         4
#                     efek_Amlodipine       1.00      1.00      1.00         3
#                      efek_Captopril       1.00      1.00      1.00         3
#              efek_Hidroclorthiazide       1.00      0.67      0.80         3
#                              gejala       1.00      0.88      0.93         8
#                   info_dev_tensibot       1.00      1.00      1.00         3
#              info_gejala_hipertensi       1.00      1.00      1.00         4
#                     info_hipertensi       0.86      0.86      0.86         7
#           info_kegiatan_minualkohol       1.00      1.00      1.00         8
#              info_kegiatan_olahraga       1.00      1.00      1.00         7
#                info_obat_hipertensi       1.00      1.00      1.00         1
#                  info_perokok_aktif       1.00      1.00      1.00         7
#                       info_tensibot       0.60      1.00      0.75         3
#                          kabar_baik       0.75      0.60      0.67         5
#                    kabar_tidak_baik       0.40      0.67      0.50         3
#               penjelasan_Amlodipine       1.00      0.50      0.67         4
#        penjelasan_Hidroclorthiazide       0.75      1.00      0.86         3
#                tidak_cek_hipertensi       1.00      0.86      0.92         7
#
#                            accuracy                           0.87       100
#                           macro avg       0.82      0.82      0.80       100
#                        weighted avg       0.89      0.87      0.87       100
# C:\Users\acer\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\acer\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\acer\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Uji Coba Model

# %%
# Menentukan input yang akan diuji
test_question = "tensibot"

# Melakukan preprocessing pada input yang akan diuji
test_question = tokenize(test_question)
test_question = [stemmer.stem(i) for i in test_question]
test_question = [i.lower() for i in test_question]

# Mengubah input yang akan diuji menjadi bentuk yang dapat digunakan oleh algoritma Multinomial Naive Bayes
test_question = vectorizer.transform([' '.join(test_question)])
print(test_question)

# Mengklasifikasikan input berdasarkan model yang telah dibuat
prediction = model.predict(test_question)

# Menampilkan hasil klasifikasi
print("Hasil klasifikasi: ", prediction[0])
# Out:
#   (0, 249)	1
# Hasil klasifikasi:  info_dev_tensibot

# %% [markdown]
# # Uji Coba Chatbot

# %%
# #Membuat dictionary untuk menyimpan jawaban sesuai dengan kategori
# jawaban_dict = {}

# #Mengambil semua kategori yang ada dalam data
# categories = df['kategori'].unique()

# #Melakukan perulangan untuk setiap kategori
# for category in categories:
#     # Mengambil jawaban yang sesuai dengan kategori yang sedang diperiksa
#     jawaban = df[df['kategori'] == category]['jawaban'].values
#     # Menambahkan jawaban ke dalam dictionary dengan kategori sebagai key
#     jawaban_dict[category] = jawaban

# %%
def import_json(file_name):
    with open(file_name, 'r') as file:
        content = json.load(file)
    return content

hipertensi_derajat1 =import_json('dataset/hipertensi_derajat1.json')
hipertensi_derajat2 =import_json('dataset/hipertensi_derajat2.json')
hipertensi_derajat3 =import_json('dataset/hipertensi_derajat3.json')
hipertensi_terisolisasi =import_json('dataset/hipertensi_terisolisasi.json')

# %%
def chatbot():
    print("Tensibot: Hai aku tensibot, gimana kabar kakak hari ini?")
    sudah = ['sudah','suda','sdh','dah','sudh','sdah','udah']
    belum = ['belum', 'belu', 'blm', 'belm', 'blum', 'lum']
    ingin = ['iya ingin', 'ya ingin', 'y ingin', 'iya ingn', 'ya ingn', 'y ingn']
    exit = True
    exit2 = True
    while exit:   
        # Mengambil input dari user
        pertanyaan = input("You: ").lower()
        # Menampilkan jawaban dari chatbot
        # Menambahkan opsi untuk keluar dari chatbot
        if pertanyaan in ingin:
            while exit2:
                print("Tensibot: Tensibot mau nanya ni berapa sistolik kakak?")
                sistolik = int(input("You:  "))
                print ("Tensibot: Tensibot mau nanya ni berapa Diastolik kakak?")
                diastolik = int(input("You:  "))
                if sistolik >= 120 and sistolik <= 129 or diastolik >=80 and diastolik <=84:
                    print("Tensibot: Wah Tekanan darah sistolik kakak "+str(sistolik)+" dan diastolik "+str(diastolik)+".\nKakak memiliki tekanan darah normal")
                    exit2 = False
                elif sistolik >=130 and sistolik <= 139 or diastolik >=84 and diastolik <=89:
                    print("Wah Tekanan darah sistolik kakak "+str(sistolik)+" dan diastolik "+str(diastolik)+".\nKakak memiliki tekanan darah tinggi normal tetap jaga kesehatan Ya..")
                    exit2 = False
                elif sistolik >=140 and sistolik <= 149 or diastolik >=90 and diastolik <= 99:
                    print("Tensibot: Wah Tekanan darah sistolik kakak "+str(sistolik)+" dan diastolik "+str(diastolik)+" kakak mengalami Hipertensi derajat 1. \nApakah sudah tahu cara pananganannya?(sudah/belum)")
                    pt = input("You: ").lower()
                    if pt in belum:
                        print("Tensibot: "+hipertensi_derajat1)
                        exit2 = False
                    elif pt in sudah:
                        print("Tensibot: Waah Bagus sekali kak. Kalau kakak bingung boleh tanya-tanya ke aku lagi ya")
                        exit2 = False
                    else:
                        print(f"Tensibot: Maaf ka aku ga ngerti {pt} maksudnya apa?")
                elif sistolik >=160  and sistolik <=179 or diastolik >=100 and diastolik <= 109:
                    print("Tensibot: Wah Tekanan darah sistolik kakak "+str(sistolik)+" dan diastolik "+str(diastolik)+" kakak mengalami Hipertensi derajat 2. \nApakah sudah tahu cara pananganannya?(sudah/belum)")
                    pt = input("You: ").lower()
                    if pt in belum:
                        print("Tensibot: "+hipertensi_derajat2)
                        exit2 = False
                    elif pt in sudah:
                            print("Tensibot: Waah Bagus sekali kak. Kalau kakak bingung boleh tanya-tanya ke aku lagi ya")
                            exit2 = False
                    else:
                        print(f"Tensibot: Maaf ka aku ga ngerti {pt} maksudnya apa?")
                elif sistolik >=180 and diastolik >=110:
                    print("Tensibot: Wah Tekanan darah sistolik kakak "+str(sistolik)+" dan diastolik "+str(diastolik)+" kakak mengalami Hipertensi derajat 3. \nApakah sudah tahu cara pananganannya?(sudah/belum)")
                    pt = input("You: ").lower()
                    if pt in belum:
                        print("Tensibot: "+hipertensi_derajat3)
                        exit2 = False
                    elif pt in sudah:
                            print("Tensibot: Waah Bagus sekali kak. Kalau kakak bingung boleh tanya-tanya ke aku lagi ya")
                            exit2 = False
                    else:
                        print(f"Tensibot: Maaf ka aku ga ngerti {pt} maksudnya apa?")
                elif sistolik >= 140 and diastolik < 90:
                    print("Tensibot: Wah Tekanan darah sistolik kakak "+str(sistolik)+" dan diastolik "+str(diastolik)+" kakak mengalami Hipertensi terisolasi. \nApakah sudah tahu cara pananganannya?(sudah/belum)")
                    pt = input("You: ").lower()
                    if pertanyaan in belum:
                        print("Tensibot: "+hipertensi_terisolisasi)
                        exit2 = False
                    elif pertanyaan in sudah:
                            print("Tensibot: Waah Bagus sekali kak. Kalau kakak bingung boleh tanya-tanya ke aku lagi ya")
                            exit2 = False
                    else:
                        print(f"Tensibot: Maaf ka aku ga ngerti {pt} maksudnya apa?")
                
        else:
            # Melakukan preprocessing pada input yang akan diuji
            pertanyaan = tokenize(pertanyaan)
            pertanyaan = [stemmer.stem(i) for i in pertanyaan]
            pertanyaan = [i.lower() for i in pertanyaan]

            # Mengubah input yang akan diuji menjadi bentuk yang dapat digunakan oleh algoritma Multinomial Naive Bayes
            pertanyaan = vectorizer.transform([' '.join(pertanyaan)])

            # Mengklasifikasikan input berdasarkan model yang telah dibuat
            prediction = model.predict(pertanyaan)

            # Mengambil jawaban yang sesuai dengan kategori yang dihasilkan dari prediksi
            answer = jawaban[prediction[0]]

            print("Tensibot: " + answer)
            if answer == "iya kaka, semoga apa yang diberikan tensibot bermanfaat ya buat kamu. kalau masih bingung kaka boleh tanya lagi sama tensibot seputar hipertensi":
                exit = False

# %%
chatbot()

# %% [markdown]
# # From scratch Multinominal Naive Bayes

# %%
# import numpy as np

# class MultinomialNaiveBayes:
#     def __init__(self):
#         self.classes = None
#         self.class_prior = None
#         self.feature_counts = None
#         self.class_counts = None
#         self.feature_prob = None
    
#     def fit(self, X, y):
#         self.classes = np.unique(y)
#         n_classes = len(self.classes)
#         n_features = X.shape[1]
        
#         self.class_prior = np.zeros(n_classes)
#         self.feature_counts = np.zeros((n_classes, n_features))
#         self.class_counts = np.zeros(n_classes)
#         self.feature_prob = np.zeros((n_classes, n_features))
        
#         for i, c in enumerate(self.classes):
#             X_c = X[y == c]
#             self.class_prior[i] = X_c.shape[0] / X.shape[0]
#             self.feature_counts[i] = np.sum(X_c, axis=0)
#             self.class_counts[i] = np.sum(self.feature_counts[i])
#             self.feature_prob[i] = (self.feature_counts[i] + 1) / (self.class_counts[i] + n_features)
    
#     def predict(self, X):
#         y_pred = np.zeros(X.shape[0])
        
#         for i, x in enumerate(X):
#             posteriors = []
#             for j, c in enumerate(self.classes):
#                 log_prior = np.log(self.class_prior[j])
#                 log_likelihood = np.sum(np.log(self.feature_prob[j]) * x)
#                 log_posterior = log_prior + log_likelihood
#                 posteriors.append(log_posterior)
                
#             y_pred[i] = self.classes[np.argmax(posteriors)]
        
#         return y_pred

# %%
# # Inisialisasi dan fit model Multinomial Naive Bayes
# model = MultinomialNB()
# model.fit(X_train, y_train)

# # Prediksi label untuk data test
# y_pred = model.predict(X_test)

# # Evaluasi performa model
# accuracy = accuracy_score(y_test, y_pred)
# print("Accuracy:", accuracy)
